# %% [markdown]
# # Analysing the arXiv
#
# *This notebook first appeared as a [blog post](//betatim.github.io/posts/analysing-the-arxiv) on [Tim Head](//betatim.github.io)'s blog.*
#
# *License: [MIT](http://opensource.org/licenses/MIT)*
#
# *(C) 2014, Tim Head.*
# *Feel free to use, distribute, and modify with the above attribution.*

# %% [markdown]
# This post is about what you can learn about scientific articles posted on the [arXiv](http://arxiv.org) by using Natural Language Processing (NLP). Said differently: I had some questions about papers posted on the arXiv and used it as an excuse to teach myself the basics of NLP. We also look at citation counts and reveal the top cited paper of 2014!
#
# The arXiv makes its data available via a simple API which allows you to download almost everything about an article short of its full text. For each article we can look up information about who has been citing it on [inspire](http://inspirehep.net/). Combined this is a powerful dataset that can answer some interesting questions like: what are the most used words, can we auto generate abstracts, what about summarising abstracts or finding the most cited article of 2014.
#
# Let's get going!
#
# First some standard imports that we will need later. Some of them you might need to install but nothing too obscure:

# %%
import time
import urllib2
import datetime
from itertools import ifilter
from collections import Counter, defaultdict
import xml.etree.ElementTree as ET

from bs4 import BeautifulSoup
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
import bibtexparser

pd.set_option('mode.chained_assignment','warn')

# %%
# %matplotlib inline

# %% [markdown]
# The `harvest` function will query the arXiv API for all articles modified between January, 1st 2010 and the end of the year 2014. This is a subtlety worth noting: with this query you will also get articles _created_ before 2010 if their entry was modified after 2010.
#
# The arXiv itself covers so many topics that it is organised into seperate arxivs (I know unfortunate doulbe use of the name arxiv), one for each topic. By default `harvest` will collect articles from the `physics:hep-ex` arxiv. This is because I am a experimental particle physicist. If you are into theory try `physics:hep-th` or `stats` if you are a stats guru. The API gives you a [full list of all sets of topics](http://export.arxiv.org/oai2?verb=ListSets) to explore.
#
# If you do not care for the technicalities of how to scrape the data skip right ahead to the first [factoid](#factoid).
#
#
# ## Harvesting articles
#
# Most of `harvest` is pretty straight forward. The API returns a big XML document containing information about at most 1000 articles which we can parse with `ElementTree` and store. If there are more than 1000 articles for a particular query we can get those using the `resumptionToken` in the XML. API access can be throttled so on occasion the arXiv will reply with a 503 error asking us to retry later. The information we harvest is stored in a `pandas` dataframe.

# %%
OAI = "{http://www.openarchives.org/OAI/2.0/}"
ARXIV = "{http://arxiv.org/OAI/arXiv/}"

def harvest(arxiv="physics:hep-ex"):
    df = pd.DataFrame(columns=("title", "abstract", "categories", "created", "id", "doi"))
    base_url = "http://export.arxiv.org/oai2?verb=ListRecords&"
    url = (base_url +
           "from=2010-01-01&until=2014-12-31&" +
           "metadataPrefix=arXiv&set=%s"%arxiv)
    
    while True:
        print "fetching", url
        try:
            response = urllib2.urlopen(url)
            
        except urllib2.HTTPError, e:
            if e.code == 503:
                to = int(e.hdrs.get("retry-after", 30))
                print "Got 503. Retrying after {0:d} seconds.".format(to)

                time.sleep(to)
                continue
                
            else:
                raise
            
        xml = response.read()

        root = ET.fromstring(xml)

        for record in root.find(OAI+'ListRecords').findall(OAI+"record"):
            arxiv_id = record.find(OAI+'header').find(OAI+'identifier')
            meta = record.find(OAI+'metadata')
            info = meta.find(ARXIV+"arXiv")
            created = info.find(ARXIV+"created").text
            created = datetime.datetime.strptime(created, "%Y-%m-%d")
            categories = info.find(ARXIV+"categories").text

            # if there is more than one DOI use the first one
            # often the second one (if it exists at all) refers
            # to an eratum or similar
            doi = info.find(ARXIV+"doi")
            if doi is not None:
                doi = doi.text.split()[0]
                
            contents = {'title': info.find(ARXIV+"title").text,
                        'id': info.find(ARXIV+"id").text,#arxiv_id.text[4:],
                        'abstract': info.find(ARXIV+"abstract").text.strip(),
                        'created': created,
                        'categories': categories.split(),
                        'doi': doi,
                        }

            df = df.append(contents, ignore_index=True)

        # The list of articles returned by the API comes in chunks of
        # 1000 articles. The presence of a resumptionToken tells us that
        # there is more to be fetched.
        token = root.find(OAI+'ListRecords').find(OAI+"resumptionToken")
        if token is None or token.text is None:
            break

        else:
            url = base_url + "resumptionToken=%s"%(token.text)
            
    return df

# %% [markdown]
# Set `harvest` running and go chat with someone for a few minutes while it gathers the information about your articles.

# %%
df = harvest()

# %% [markdown]
# What does all that stuff we just downloaded look like? Here are the first five entries in the dataframe:

# %%
df.head()
# Out:
#                                                title  \
# 0  Measurement of the Hadronic Form Factor in D0 ...
# 1  Measurement of B(D_S^+ --> ell^+ nu) and the D...
# 2  A unified analysis of the reactor neutrino pro...
# 3  Measurement of Decay Amplitudes of B -->(c cba...
# 4  Measurement of the Decay Constant $f_D{_S^+}$ ...
#
#                                             abstract  \
# 0  The shape of the hadronic form factor f+(q2) i...
# 1  We examine e+e- --> Ds- Ds*+ and Ds*- Ds+ inte...
# 2  We present in this article a detailed quantita...
# 3  We perform the first three-dimensional measure...
# 4  We measure the decay constant fDs using the Ds...
#
#                   categories    created         id  \
# 0                   [hep-ex] 2007-03-31  0704.0020
# 1  [hep-ex, hep-lat, hep-ph] 2007-04-03  0704.0437
# 2                   [hep-ex] 2007-04-04  0704.0498
# 3                   [hep-ex] 2007-04-04  0704.0522
# 4  [hep-ex, hep-lat, hep-ph] 2007-04-04  0704.0629
#
#                               doi  \
# 0  doi:10.1103/PhysRevD.76.052005
# 1      10.1103/PhysRevD.76.072002
# 2  10.1088/1742-6596/110/8/082013
# 3      10.1103/PhysRevD.76.031102
# 4   10.1103/PhysRevLett.99.071802
#
#                                             cited_by
# 0  [{u'slaccitation': u'%%CITATION = ARXIV:1411.3...
# 1  [{u'author': u'Yelton, John M.', u'journal': u...
# 2  [{u'author': u'Queval, Rachel', u'title': u'Ch...
# 3  [{u'author': u'Giurgiu, Gavril', u'journal': u...
# 4  [{u'author': u'Jackson, Graham', u'type': u'ar...

# %% [markdown]
# ## First factoid
# <a id="factoid"></a>

# %%
def bar_chart(items):
    """Make a bar chart showing the count associated with each key
    
    `items` is a list of (key, count) pairs.
    """
    width = 0.5
    ind = np.arange(len(items))
    fig, ax = plt.subplots(figsize=(8,8))
    rects1 = ax.bar(ind, zip(*items)[1], width, color='r')
    ax.set_xticks(ind+width)
    ax.set_xticklabels(zip(*items)[0])
    fig.autofmt_xdate()
    plt.show()

edits_per_year = Counter(df.created.map(lambda x: x.year))
bar_chart(edits_per_year.items())
new_articles = sum(edits_per_year[year] for year in (2010,2011,2012,2013,2014))
print "Unique arXiv IDs edited between 2010 and 2014:", len(df.id.unique())
print "of which %i entries were created in that time period."%(new_articles)
# Out:
# Unique arXiv IDs edited between 2010 and 2014: 16321
# of which 11958 entries were created in that time period.

# %% [markdown]
# Here is our first factoid about the arXiv: There are about 16000 articles in `hep-ex` which were edited between the beginning of 2010 and the end of 2014. Including about 12000 newly created articles. The other 4000 papers were created before 2010 and were updated after creation. Amazing to see that papers created in 1994 were still being edited almost ten years later!
#
# Let's take a look at those, maybe there is something interesting:

# %%
df[df.created<datetime.date(1995,1,1)]
# Out:
#                                                    title  \
# 13366  DUMAND and AMANDA: High Energy Neutrino Astrop...
# 13375  Detection of nuclear recoils in prototype dark...
# 15144  Precise Measurement of the Left-Right Cross Se...
# 15145  An optimal method of moments to measure the ch...
# 15146  Observation of Anisotropic Event Shapes and Tr...
# 15147  Measurement of the Charged Multiplicity of $Z ...
# 15148  Evidence for Top Quark Production in $\bar{p}p...
# 15149  Precise Determination of the Weak Mixing Angle...
# 15150  A Neural Network for Locating the Primary Vert...
# 15151  Semileptonic Branching Fraction of Charged and...
# 15152  Measurement of the B -> D^* l nu Branching Fra...
# 15153  Spin Asymmetry in Muon--Proton Deep Inelastic ...
# 15154  Measurement of the polarization of Lambda0 Ant...
# 15155        Search for slowly moving magnetic monopoles
# 15156  Polarized Bhabha Scattering and a Precision Me...
# 15157  A Measurement of the $D^{*\pm}$ Cross Section ...
# 15158  Measurement of the $D^{*\pm}$ Cross Section us...
# 15159  $K^0(\bar{K^0})$ Production in Two-Photon Proc...
# 15160  New Tagging Method of B Flavor of Neutral B Me...
# 15161  Kinematic Evidence for Top Quark Pair Producti...
# 15162  Feasibility Study of Single-Photon Counting Us...
# 15163  Measurement of inclusive electron cross sectio...
# 15164  Measurement of the forward-backward asymmetrie...
# 15165  J/psi,psi(2S) to mu+ mu- and B to J/psi,psi(2S...
# 15166  Measurement of inclusive particle spectra and ...
# 15167               Measurement of the Bs Meson Lifetime
# 16101  Exclusive Hadronic B Decays to Charm and Charm...
# 16102         Observation of a New Charmed Strange Meson
# 16103  Study of the Decay $\Lambda_c \to \Lambda l^+ ...
# 16104  Precision Measurement of the $D_s^{*+}- D_s^+$...
# 16105  A Measurement of ${\cal B}(D_s \to \phi l^+ \n...
# 16106  Measurement of Cabibbo Suppressed Decays of th...
# 16107  Production and Decay of D_1(2420)^0 and D_2^*(...
# 16108  Two-Photon Production of Charged Pion and Kaon...
# 16109  Measurement of the Branching Fraction for D^+ ...
# 16110  Measurement of the Spin-Dependent Structure Fu...
# 16111  A Measurement of the Branching Fraction ${\cal...
# 16112                    Supersymmetry at the DiTevatron
# 16113  Detecting Tau Neutrino Oscillations at PeV Ene...
#
#                                                 abstract  \
# 13366  The field of high energy neutrino astrophysics...
# 13375  This work is part of an ongoing project to dev...
# 15144  We present a precise measurement of the left-r...
# 15145  Parity violation at LEP or SLC can be measured...
# 15146  Event shapes for Au + Au collisions at 11.4 Ge...
# 15147  Using an impact parameter tag to select an enr...
# 15148  We summarize a search for the top quark with t...
# 15149  In the 1993 SLC/SLD run, the SLD recorded 50,0...
# 15150  Using simulated collider data for $p+p\rightar...
# 15151  An examination of leptons in ${\Upsilon (4S)}$...
# 15152  We study the exclusive semileptonic B meson de...
# 15153  We measured the spin asymmetry in the scatteri...
# 15154  The polarization of Lambda0, AntiLambda0, Sigm...
# 15155  We report a search for slowly moving magnetic ...
# 15156  We present the first measurement of the left-r...
# 15157  We have measured the inclusive $D^{*\pm}$ prod...
# 15158  The differential cross section of $d\sigma(e^+...
# 15159  We have carried out an inclusive measurement o...
# 15160  In CP violation measurements in asymmetric B-f...
# 15161  We present a study of $W+$multijet events that...
# 15162  The fine-mesh phototube is one type of photode...
# 15163  We have studied open charm production in $\gam...
# 15164  We have measured, with electron tagging, the f...
# 15165  This paper presents a measurement of J/psi,psi...
# 15166  Inclusive momentum spectra are measured for al...
# 15167  The lifetime of the $B_s$ meson is measured us...
# 16101  We have fully reconstructed decays of both B0 ...
# 16102  Using the CLEO-II detector, we have obtained e...
# 16103  Using the CLEO II detector at CESR, we observe...
# 16104  We have measured the vector-pseudoscalar mass ...
# 16105  Using the CLEO~II detector at CESR, we have me...
# 16106  Branching ratios for the dominant Cabibbo-supp...
# 16107  We have investigated $D^{+}\pi^{-}$ and $D^{*+...
# 16108  A measurement of the cross section for the com...
# 16109  Using the CLEO-II detector at CESR we have mea...
# 16110  We have measured the spin-dependent structure ...
# 16111  Using data from the CLEO II detector at CESR, ...
# 16112  We study the signals for supersymmetry at the ...
# 16113  It is suggested that a large deep underocean (...
#
#                        categories    created                id  \
# 13366          [astro-ph, hep-ex] 1994-12-06  astro-ph/9412019
# 13375          [cond-mat, hep-ex] 1994-11-17  cond-mat/9411072
# 15144            [hep-ex, hep-ph] 1994-04-27    hep-ex/9404001
# 15145                    [hep-ex] 1994-05-11    hep-ex/9405002
# 15146                    [hep-ex] 1994-05-13    hep-ex/9405003
# 15147            [hep-ex, hep-ph] 1994-05-13    hep-ex/9405004
# 15148            [hep-ex, hep-ph] 1994-05-16    hep-ex/9405005
# 15149                    [hep-ex] 1994-05-20    hep-ex/9405011
# 15150                    [hep-ex] 1994-06-21    hep-ex/9406003
# 15151                    [hep-ex] 1994-06-23    hep-ex/9406004
# 15152                    [hep-ex] 1994-06-24    hep-ex/9406005
# 15153                    [hep-ex] 1994-08-06    hep-ex/9408001
# 15154                    [hep-ex] 1994-09-16    hep-ex/9409001
# 15155                    [hep-ex] 1994-10-05    hep-ex/9410006
# 15156                    [hep-ex] 1994-10-10    hep-ex/9410009
# 15157                    [hep-ex] 1994-11-29    hep-ex/9411002
# 15158                    [hep-ex] 1994-12-01    hep-ex/9412001
# 15159                    [hep-ex] 1994-12-05    hep-ex/9412003
# 15160                    [hep-ex] 1994-12-08    hep-ex/9412005
# 15161                    [hep-ex] 1994-12-13    hep-ex/9412009
# 15162                    [hep-ex] 1994-12-13    hep-ex/9412010
# 15163                    [hep-ex] 1994-12-16    hep-ex/9412011
# 15164                    [hep-ex] 1994-12-18    hep-ex/9412012
# 15165                    [hep-ex] 1994-12-23    hep-ex/9412013
# 15166                    [hep-ex] 1994-12-27    hep-ex/9412015
# 15167                    [hep-ex] 1994-12-27    hep-ex/9412017
# 16101            [hep-ph, hep-ex] 1994-03-15    hep-ph/9403295
# 16102            [hep-ph, hep-ex] 1994-03-21    hep-ph/9403325
# 16103            [hep-ph, hep-ex] 1994-03-21    hep-ph/9403326
# 16104            [hep-ph, hep-ex] 1994-03-21    hep-ph/9403327
# 16105            [hep-ph, hep-ex] 1994-03-21    hep-ph/9403328
# 16106            [hep-ph, hep-ex] 1994-03-21    hep-ph/9403329
# 16107            [hep-ph, hep-ex] 1994-03-24    hep-ph/9403359
# 16108            [hep-ph, hep-ex] 1994-03-28    hep-ph/9403379
# 16109            [hep-ph, hep-ex] 1994-03-28    hep-ph/9403382
# 16110            [hep-ph, hep-ex] 1994-04-15    hep-ph/9404270
# 16111            [hep-ph, hep-ex] 1994-04-20    hep-ph/9404310
# 16112            [hep-ph, hep-ex] 1994-06-07    hep-ph/9406248
# 16113  [hep-ph, astro-ph, hep-ex] 1994-08-15    hep-ph/9408296
#
#                                 doi  \
# 13366                          None
# 13375  10.1016/0168-9002(95)00036-4
# 15144     10.1103/PhysRevLett.73.25
# 15145  10.1016/0168-9002(94)90847-8
# 15146   10.1103/PhysRevLett.73.2532
# 15147   10.1103/PhysRevLett.72.3145
# 15148    10.1103/PhysRevLett.73.225
# 15149                          None
# 15150  10.1016/0168-9002(94)01133-8
# 15151   10.1103/PhysRevLett.73.3503
# 15152      10.1103/PhysRevD.51.1014
# 15153  10.1016/0370-2693(94)00968-6
# 15154            10.1007/BF01291194
# 15155  10.1016/0920-5632(94)90257-7
# 15156   10.1103/PhysRevLett.74.2880
# 15157      10.1103/PhysRevD.50.1879
# 15158  10.1016/0370-2693(94)91515-6
# 15159  10.1016/0370-2693(94)90315-8
# 15160          10.1143/JPSJ.63.3542
# 15161      10.1103/PhysRevD.51.4623
# 15162  10.1016/0168-9002(93)90749-8
# 15163  10.1016/0370-2693(94)01349-7
# 15164  10.1016/0370-2693(94)91310-2
# 15165                          None
# 15166  10.1016/0370-2693(94)01685-6
# 15167   10.1103/PhysRevLett.74.4988
# 16101        10.1103/PhysRevD.50.43
# 16102   10.1103/PhysRevLett.72.1972
# 16103  10.1016/0370-2693(94)90295-X
# 16104      10.1103/PhysRevD.50.1884
# 16105  10.1016/0370-2693(94)90416-2
# 16106   10.1103/PhysRevLett.73.1079
# 16107  10.1016/0370-2693(94)90968-7
# 16108      10.1103/PhysRevD.50.3027
# 16109   10.1103/PhysRevLett.72.2328
# 16110  10.1016/0370-2693(94)90793-5
# 16111   10.1103/PhysRevLett.72.3762
# 16112      10.1103/PhysRevD.50.5676
# 16113  10.1016/0927-6505(94)00043-3
#
#                                                 cited_by
# 13366  [{u'author': u'Al Samarai, Imen', u'type': u'a...
# 13375  [{u'doi': u'10.1016/j.astropartphys.2004.06.00...
# 15144  [{u'doi': u'10.1088/1742-6596/335/1/012078', u...
# 15145                                                 []
# 15146  [{u'primaryclass': u'nucl-th', u'author': u'Wa...
# 15147  [{u'doi': u'10.1140/epjc/s2005-02424-5', u'pri...
# 15148  [{u'primaryclass': u'hep-ex', u'author': u'Ger...
# 15149  [{u'doi': u'10.1016/0370-1573(95)00072-0', u'a...
# 15150                                                 []
# 15151  [{u'author': u'Ivarsson, Jenny', u'title': u'P...
# 15152  [{u'author': u'Borean, Cristiano', u'type': u'...
# 15153  [{u'primaryclass': u'nucl-ex', u'author': u'Pa...
# 15154  [{u'doi': u'10.1088/1742-6596/509/1/012056', u...
# 15155                                                 []
# 15156  [{u'author': u'Quast, Gunther', u'title': u'Me...
# 15157  [{u'author': u'Ngac, An Bang', u'title': u'Mea...
# 15158  [{u'author': u'Ngac, An Bang', u'title': u'Mea...
# 15159  [{u'doi': u'10.1016/S0370-2693(02)01769-0', u'...
# 15160  [{u'author': u'Foland, Andrew Dean', u'title':...
# 15161  [{u'author': u'Hinchliffe, Ian and Paige, FE a...
# 15162  [{u'doi': u'10.1140/epjc/s10052-014-3026-9', u...
# 15163  [{u'doi': u'10.1016/S0370-2693(02)01769-0', u'...
# 15164  [{u'doi': u'10.1103/PhysRevD.65.053002', u'pri...
# 15165  [{u'slaccitation': u'%%CITATION = ARXIV:1411.3...
# 15166  [{u'slaccitation': u'%%CITATION = ARXIV:1412.2...
# 15167  [{u'doi': u'10.1007/s00601-014-0871-x', u'prim...
# 16101  [{u'author': u'Sabelli, Chiara', u'title': u'T...
# 16102  [{u'slaccitation': u'%%CITATION = ARXIV:1410.5...
# 16103  [{u'doi': u'10.1140/epjc/s10052-014-3194-7', u...
# 16104  [{u'doi': u'10.1007/JHEP06(2013)065', u'primar...
# 16105  [{u'doi': u'10.1103/RevModPhys.84.65', u'prima...
# 16106  [{u'doi': u'10.1103/PhysRevD.87.073016', u'pri...
# 16107  [{u'slaccitation': u'%%CITATION = ARXIV:1410.5...
# 16108  [{u'slaccitation': u'%%CITATION = ARXIV:1307.0...
# 16109  [{u'doi': u'10.1103/RevModPhys.84.65', u'prima...
# 16110  [{u'doi': u'10.1103/PhysRevD.90.012009', u'pri...
# 16111  [{u'primaryclass': u'hep-ex', u'author': u'Amh...
# 16112  [{u'doi': u'10.1103/PhysRevD.82.035009', u'pri...
# 16113  [{u'slaccitation': u'%%CITATION = ARXIV:1412.1...

# %% [markdown]
# After scrolling through the list I can not spot a particular pattern to the edits. Though it does seem like the list contains articles on interesting topics like evidence for the top quark (index 15148), PeV $\tau$ neutrinos (index 16113) and an article about determining the weak mixing angle at SLD (index 15149).
#
# ## Collecting citations
#
# Unfortunately Inspire does not provide a real API, so we have to scrape their webpages to get what we want. The `get_cites` function will look up the citations of an article by its `arxiv_id`. Having to make one HTTP request per article means this takes quite a while. So set it going and come back after a few hours. We process articles in chunks of 1000 to get some feedback as well as being able to resume if something goes wrong:

# %%
def get_cites(arxiv_id):
    cites = []
    base_url = "http://inspirehep.net/search?p=refersto:%s&of=hx&rg=250&jrec=%i"
    offset = 1
    
    while True:
        print base_url%(arxiv_id, offset)
        response = urllib2.urlopen(base_url%(arxiv_id, offset))
        xml = response.read()
        soup = BeautifulSoup(xml)

        refs = "\n".join(cite.get_text() for cite in soup.findAll("pre"))

        bib_database = bibtexparser.loads(refs)
        if bib_database.entries:
            cites += bib_database.entries
            offset += 250
            
        else:
            break

    return cites

step = 1000
for N in range(0,17):
    print N
    cites = df['id'][N*step:(N+1)*step].map(get_cites)
    df.ix[N*step:(N+1)*step -1,'cited_by'] = cites

# %% [markdown]
# ## Data preservation
#
# After investing so much time to gather the raw data it is a good idea to store it locally so we do not have to scrape it all again later:

# %%
store = pd.HDFStore("/Users/thead/git/arxiv-experiments/hep-ex.h5")
#store['df'] = df
#df = store['df']
store.close()

# %% [markdown]
# ## Word counts
#
# Let's get to answering some questions. What are the ten most used words in `hep-ex` abstracts?

# %%
word_bag = " ".join(df.abstract.apply(lambda t: t.lower()))

Counter(word_bag.split()).most_common(n=10)
# Out:
# [('the', 161889),
#  ('of', 79075),
#  ('and', 54236),
#  ('in', 41418),
#  ('a', 38591),
#  ('to', 36425),
#  ('for', 25128),
#  ('is', 23440),
#  ('with', 23015),
#  ('we', 22510)]

# %% [markdown]
# Not too enlightening, boring little words close out the top ten. These words are known as stopwords and the `NLTK` library provides a list of all of them. So let's remove them as well as basic mathematical symbols:

# %%
from nltk.corpus import stopwords

stops = [word for word in stopwords.words('english')]
stops += ["=", "->"]
words = filter(lambda w: w not in stops,
               word_bag.split())
top_twenty = Counter(words).most_common(n=20)

bar_chart(top_twenty)

# %% [markdown]
# Experimental physics is all about data afterall! A shame that `model` beats `detector` but probably that is inevitable as there are many more theoretical models than experimental detectors. The `higgs` boson beats the `neutrino` but they reign supreme over all the other particles.
#
# Towards the bottom we have `measurements` and `measured`. These should probably be counted as one entry, together with `measurement`, `measuring`, etc. The easiest way to achieve this is to stem the words before counting. [Stemming](http://en.wikipedia.org/wiki/Stemming) is the process of reducing derived words to their stem, for example:

# %%
import nltk.stem as stem

porter = stem.PorterStemmer()
for w in ("measurement", "measurements", "measured", "measure"):
    print w, "->", porter.stem(w)
# Out:
# measurement -> measur
# measurements -> measur
# measured -> measur
# measure -> measur

# %% [markdown]
# Like in this case the stem does not have to be a real word itself. By stemming words before counting how often they occur the entries for `measurements` and `measured` get added together. Using the stem of every word we get the following ranking:

# %%
word_stems = map(lambda w: (porter.stem(w),w), words)
stem2words = defaultdict(set)
for stem, word in word_stems:
    stem2words[stem].add(word)

top_twenty = Counter(w[0] for w in word_stems).most_common(n=20)

bar_chart(top_twenty)

# list all words which correspond to each top twenty stem
for stem,count in top_twenty:
    print stem, "<-", ", ".join(stem2words[stem])
# Out:
# measur <- measuring, measures, measurment, measurements, measure, measurable, measurably, measureable, measurability, measurement, measured
# decay <- decayed, decays, decaying, decay
# use <- use, used, useful, uses, usefulness, using
# data <- data
# mass <- masses, mass
# model <- models, modeled, modelled, modelling, modeling, model
# result <- resulted, resultant, resulting, results, result
# energi <- energies, energy
# product <- product, productive, productivity, productions, production, products
# detector <- detector, detectors
# neutrino <- neutrino, neutrinos
# present <- presently, presented, presentations, presents, presentational, presenting, presentation, present
# search <- searches, searchs, search, searching, searched
# new <- new
# studi <- studying, study, studied, studies
# observ <- observational, observable, observation, observer, observes, observed, observe, observations, observables, observability, observing
# standard <- standards, standardize, standardized, standard
# higg <- higgs
# cross <- crossing, crossings, crosses, crossed, cross
# experi <- experiement, experiments, experiences, experiment, experience

# %% [markdown]
# Turns out experimental phsics is all about measuring things. The stemming is not perfect, but good enough for now.
#
#
# ## Cite me, cite me, no cite me!
#
# In science citations is the currency used to measure the success of a paper. What does the distribution of citations look like then?
#
# A simple question to ask is: how often are articles cited? As articles have to be read and understood before they can be cited we only look at articles created before the beginning of 2014.

# %%
before_2014 = datetime.datetime(2014,1,1)
plt.hist(df[df.created<before_2014].cited_by.map(len),
         bins=200, normed=True, range=(0,200))
plt.xlabel("Number of citations")
plt.ylabel("Fraction")

# %% [markdown]
# This plot shows the fraction of articles cited zero, one, two, three, ... times. The single most likely number of citations for an article on `hep-ex` is zero! A whopping 13% of articles never get cited and nearly a third of articles are cited less than four times.

# %%
df['citation_count'] = df.cited_by.map(len)
df[df.created<before_2014]['citation_count'].describe()
# Out:
# count    14059.000000
# mean        32.630486
# std        100.773436
# min          0.000000
# 25%          2.000000
# 50%         10.000000
# 75%         31.000000
# max       4138.000000
# Name: citation_count, dtype: float64

# %% [markdown]
# The average number of citations is about 33. The average is misleading for a steeply falling distribution like this, afterall we reach the 50% percentile at only 10 citations!
#
# ## Citations top ten
# <a id="topten"></a>
#
# The prize for most cited paper with a whopping 4138 citations goes to:

# %%
df.iloc[df.citation_count.idxmax()]
# Out:
# title             New Generation of Parton Distributions with Un...
# abstract          A new generation of parton distribution functi...
# categories                                         [hep-ph, hep-ex]
# created                                         2002-01-21 00:00:00
# id                                                   hep-ph/0201195
# doi                                   10.1088/1126-6708/2002/07/012
# cited_by          [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...
# citation_count                                                 4138
# Name: 15779, dtype: object

# %% [markdown]
# Read the paper yourself: [New Generation of Parton Distributions with Uncertainties from Global QCD Analysis](http://arxiv.org/abs/hep-ph/0201195) and see if you agree.
#
# We can also easily compute the top ten papers. This is an interesting mix of articles. Number two and three are the papers by the [ATLAS](http://atlas.ch) and [CMS](http://cms.web.cern.ch/) experiments reporting on the discovery of the [Higgs boson](http://en.wikipedia.org/wiki/Higgs_boson). While most of the papers in the top ten are older these two were only published in 2012 and have already overtaken the top quark discovery which was published in 1995! Curious fact, the ATLAS paper has ever so few more citations than the CMS one.

# %%
df.sort('citation_count', ascending=False).head(10)
# Out:
#                                                    title  \
# 15779  New Generation of Parton Distributions with Un...
# 7371   Observation of a new particle in the search fo...
# 7372   Observation of a new boson at a mass of 125 Ge...
# 15181  Observation of Top Quark Production in Pbar-P ...
# 16241  Direct Evidence for Neutrino Flavor Transforma...
# 15690  HERWIG 6.5: an event generator for Hadron Emis...
# 14026  First Results from KamLAND: Evidence for React...
# 16152                             A Supersymmetry Primer
# 16235  Measurement of the rate of nu_e + d --> p + p ...
# 13678                                 The BABAR Detector
#
#                                                 abstract  \
# 15779  A new generation of parton distribution functi...
# 7371   A search for the Standard Model Higgs boson in...
# 7372   Results are presented from searches for the st...
# 15181  We establish the existence of the top quark us...
# 16241  Observations of neutral current neutrino inter...
# 15690  HERWIG is a general-purpose Monte Carlo event ...
# 14026  KamLAND has been used to measure the flux of $...
# 16152  I provide a pedagogical introduction to supers...
# 16235  Solar neutrinos from the decay of $^8$B have b...
# 13678  BABAR, the detector for the SLAC PEP-II asymme...
#
#                      categories    created               id  \
# 15779          [hep-ph, hep-ex] 2002-01-21   hep-ph/0201195
# 7371                   [hep-ex] 2012-07-31        1207.7214
# 7372                   [hep-ex] 2012-07-31        1207.7235
# 15181          [hep-ex, hep-ph] 1995-03-02   hep-ex/9503002
# 16241         [nucl-ex, hep-ex] 2002-04-21  nucl-ex/0204008
# 15690          [hep-ph, hep-ex] 2000-11-29   hep-ph/0011363
# 14026         [hep-ex, nucl-ex] 2002-12-09   hep-ex/0212021
# 16152  [hep-ph, hep-ex, hep-th] 1997-09-15   hep-ph/9709356
# 16235         [nucl-ex, hep-ex] 2001-06-18  nucl-ex/0106015
# 13678                  [hep-ex] 2001-05-16   hep-ex/0105044
#
#                                   doi  \
# 15779   10.1088/1126-6708/2002/07/012
# 7371   10.1016/j.physletb.2012.08.020
# 7372   10.1016/j.physletb.2012.08.021
# 15181     10.1103/PhysRevLett.74.2626
# 16241   10.1103/PhysRevLett.89.011301
# 15690   10.1088/1126-6708/2001/01/010
# 14026   10.1103/PhysRevLett.90.021802
# 16152                            None
# 16235   10.1103/PhysRevLett.87.071301
# 13678   10.1016/S0168-9002(01)02012-5
#
#                                                 cited_by  citation_count
# 15779  [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            4138
# 7371   [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            3653
# 7372   [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            3592
# 15181  [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            2519
# 16241  [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            2425
# 15690  [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            2324
# 14026  [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            2235
# 16152  [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            2160
# 16235  [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            2030
# 13678  [{u'title': u'Measurement of the Partial Branc...            1828

# %% [markdown]
# There are many more interesting things to be done with analysing the words used in abstracts as well as anlysing who cites who. This will be covered in the second part of this post as this one is already fairly lengthy.
#
# Just one more thing, the top cited paper of 2014: [First combination of Tevatron and LHC measurements of the top-quark mass](http://arxiv.org/abs/1403.4427) celebrating collaboration across the globe:

# %%
df.iloc[df[df.created>before_2014].citation_count.idxmax()]
# Out:
# title             First combination of Tevatron and LHC measurem...
# abstract          We present a combination of measurements of th...
# categories                                                 [hep-ex]
# created                                         2014-03-18 00:00:00
# id                                                        1403.4427
# doi                                                            None
# cited_by          [{u'slaccitation': u'%%CITATION = ARXIV:1412.1...
# citation_count                                                  118
# Name: 11494, dtype: object
